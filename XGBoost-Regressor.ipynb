# %%
import numpy as np
import pandas as pd
import xgboost as xgb
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import Ridge
from scipy.stats import skew

# -----------------------------
# 1. Data Loading
# -----------------------------
train = pd.read_csv('data/train.csv')
test = pd.read_csv('data/test.csv')
test_ID = test['Id']  # Save test IDs for submission

# -----------------------------
# 2. Preprocessing & Feature Engineering
# -----------------------------
# Log-transform the target variable for a better distribution
train["SalePrice"] = np.log1p(train["SalePrice"])

# Combine train and test data for consistent preprocessing
ntrain = train.shape[0]
all_data = pd.concat((train.drop('SalePrice', axis=1), test)).reset_index(drop=True)

# Fill missing values:
# - For numeric features, fill with the median
# - For categorical features, fill with "None"
numeric_feats = all_data.select_dtypes(include=[np.number]).columns
for col in numeric_feats:
    all_data[col].fillna(all_data[col].median(), inplace=True)

categorical_feats = all_data.select_dtypes(include=[object]).columns
for col in categorical_feats:
    all_data[col].fillna("None", inplace=True)

# Transform skewed numeric features (threshold: absolute skew > 0.75)
skewed_feats = all_data[numeric_feats].apply(lambda x: skew(x.dropna()))
skewed_features = skewed_feats[abs(skewed_feats) > 0.75].index
print("Skewed features:", list(skewed_features))
for feat in skewed_features:
    all_data[feat] = np.log1p(all_data[feat])

# One-hot encode categorical features
all_data = pd.get_dummies(all_data)

# Split the data back into training and test sets
train_data = all_data[:ntrain]
test_data = all_data[ntrain:]
y = train["SalePrice"]

# -----------------------------
# 3. Train / Holdout Split for Grid Search
# -----------------------------
X_train, X_holdout, y_train, y_holdout = train_test_split(
    train_data, y, test_size=0.2, random_state=42
)

# -----------------------------
# 4. Grid Search with XGBoost
# -----------------------------
# Define a modest parameter grid (including regularization parameters) to keep runtime reasonable
param_grid = {
    "max_depth": [3, 4],
    "learning_rate": [0.01, 0.05],
    "n_estimators": [100, 200],
    "reg_alpha": [0, 0.1, 1],
    "reg_lambda": [1, 1.5],
    "subsample": [0.8],
    "colsample_bytree": [0.8]
}

xgb_model = xgb.XGBRegressor(
    objective='reg:squarederror',
    random_state=42,
    n_jobs=-1
)

grid_search = GridSearchCV(
    estimator=xgb_model,
    param_grid=param_grid,
    scoring='neg_mean_squared_error',  # Higher is better in GridSearchCV
    cv=3,
    verbose=1,
    n_jobs=-1
)

grid_search.fit(X_train, y_train)
print("Best XGBoost parameters found:", grid_search.best_params_)
print("Best CV score (negative MSE):", grid_search.best_score_)

# -----------------------------
# 5. Evaluation on the Holdout Set with XGBoost
# -----------------------------
best_xgb = grid_search.best_estimator_
holdout_preds_xgb = best_xgb.predict(X_holdout)
holdout_rmse_xgb = np.sqrt(mean_squared_error(np.expm1(y_holdout), np.expm1(holdout_preds_xgb)))
print("Holdout RMSE (XGBoost):", holdout_rmse_xgb)

# -----------------------------
# 6. Refit Best XGBoost on Full Training Data with Early Stopping
# -----------------------------
X_full_train, X_val, y_full_train, y_val = train_test_split(
    train_data, y, test_size=0.1, random_state=42
)

best_xgb.fit(
    X_full_train, y_full_train,
    eval_set=[(X_val, y_val)],
    verbose=True
)

# -----------------------------
# 7. Train a Ridge Regression Model
# -----------------------------
ridge = Ridge()
ridge_param_grid = {
    "alpha": [0.1, 1.0, 10.0]
}

ridge_grid = GridSearchCV(
    estimator=ridge,
    param_grid=ridge_param_grid,
    scoring='neg_mean_squared_error',
    cv=3,
    verbose=1,
    n_jobs=-1
)

ridge_grid.fit(X_train, y_train)
print("Best Ridge parameters found:", ridge_grid.best_params_)
best_ridge = ridge_grid.best_estimator_

# Evaluate Ridge on the holdout set
holdout_preds_ridge = best_ridge.predict(X_holdout)
holdout_rmse_ridge = np.sqrt(mean_squared_error(np.expm1(y_holdout), np.expm1(holdout_preds_ridge)))
print("Holdout RMSE (Ridge):", holdout_rmse_ridge)

# -----------------------------
# 8. Ensemble Predictions on Test Set
# -----------------------------
# Get predictions from both models on the test set
test_preds_xgb = best_xgb.predict(test_data)
test_preds_ridge = best_ridge.predict(test_data)

# Ensemble: weighted average of XGBoost and Ridge predictions
# Here we weight XGBoost higher; you can tune these weights further.
ensemble_preds = 0.7 * test_preds_xgb + 0.3 * test_preds_ridge
ensemble_preds = np.expm1(ensemble_preds)  # reverse the log transform

# -----------------------------
# 9. Create Submission File
# -----------------------------
submission = pd.DataFrame({
    "Id": test_ID,
    "SalePrice": ensemble_preds
})
submission.to_csv("submission.csv", index=False)
print("Submission file created: submission.csv")
# Out:
# Skewed features: ['MSSubClass', 'LotFrontage', 'LotArea', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtHalfBath', 'KitchenAbvGr', 'TotRmsAbvGrd', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal']
# Fitting 3 folds for each of 48 candidates, totalling 144 fits
# Best XGBoost parameters found: {'colsample_bytree': 0.8, 'learning_rate': 0.05, 'max_depth': 4, 'n_estimators': 200, 'reg_alpha': 0, 'reg_lambda': 1, 'subsample': 0.8}
# Best CV score (negative MSE): -0.01578985541269833
# Holdout RMSE (XGBoost): 25268.083955857885
# [0]	validation_0-rmse:0.42818
# [1]	validation_0-rmse:0.41310
# [2]	validation_0-rmse:0.39931
# [3]	validation_0-rmse:0.38535
# [4]	validation_0-rmse:0.37365
# [5]	validation_0-rmse:0.35993
# [6]	validation_0-rmse:0.34791
# [7]	validation_0-rmse:0.33701
# [8]	validation_0-rmse:0.32623
# [9]	validation_0-rmse:0.31522
# [10]	validation_0-rmse:0.30600
# [11]	validation_0-rmse:0.29652
# [12]	validation_0-rmse:0.28834
# [13]	validation_0-rmse:0.28040
# [14]	validation_0-rmse:0.27264
# [15]	validation_0-rmse:0.26527
# [16]	validation_0-rmse:0.25872
# [17]	validation_0-rmse:0.25234
# [18]	validation_0-rmse:0.24692
# [19]	validation_0-rmse:0.24205
# [20]	validation_0-rmse:0.23617
# [21]	validation_0-rmse:0.23068
# [22]	validation_0-rmse:0.22584
# [23]	validation_0-rmse:0.22037
# [24]	validation_0-rmse:0.21561
# [25]	validation_0-rmse:0.21117
# [26]	validation_0-rmse:0.20691
# [27]	validation_0-rmse:0.20265
# [28]	validation_0-rmse:0.19816
# [29]	validation_0-rmse:0.19462
# [30]	validation_0-rmse:0.19100
# [31]	validation_0-rmse:0.18781
# [32]	validation_0-rmse:0.18471
# [33]	validation_0-rmse:0.18166
# [34]	validation_0-rmse:0.17929
# [35]	validation_0-rmse:0.17658
# [36]	validation_0-rmse:0.17406
# [37]	validation_0-rmse:0.17188
# [38]	validation_0-rmse:0.16891
# [39]	validation_0-rmse:0.16670
# [40]	validation_0-rmse:0.16361
# [41]	validation_0-rmse:0.16095
# [42]	validation_0-rmse:0.15846
# [43]	validation_0-rmse:0.15618
# [44]	validation_0-rmse:0.15412
# [45]	validation_0-rmse:0.15241
# [46]	validation_0-rmse:0.15079
# [47]	validation_0-rmse:0.14907
# [48]	validation_0-rmse:0.14777
# [49]	validation_0-rmse:0.14596
# [50]	validation_0-rmse:0.14432
# [51]	validation_0-rmse:0.14307
# [52]	validation_0-rmse:0.14146
# [53]	validation_0-rmse:0.14043
# [54]	validation_0-rmse:0.13950
# [55]	validation_0-rmse:0.13814
# [56]	validation_0-rmse:0.13657
# [57]	validation_0-rmse:0.13601
# [58]	validation_0-rmse:0.13532
# [59]	validation_0-rmse:0.13459
# [60]	validation_0-rmse:0.13325
# [61]	validation_0-rmse:0.13225
# [62]	validation_0-rmse:0.13213
# [63]	validation_0-rmse:0.13148
# [64]	validation_0-rmse:0.13025
# [65]	validation_0-rmse:0.12911
# [66]	validation_0-rmse:0.12829
# [67]	validation_0-rmse:0.12786
# [68]	validation_0-rmse:0.12730
# [69]	validation_0-rmse:0.12633
# [70]	validation_0-rmse:0.12535
# [71]	validation_0-rmse:0.12490
# [72]	validation_0-rmse:0.12424
# [73]	validation_0-rmse:0.12355
# [74]	validation_0-rmse:0.12296
# [75]	validation_0-rmse:0.12281
# [76]	validation_0-rmse:0.12244
# [77]	validation_0-rmse:0.12203
# [78]	validation_0-rmse:0.12190
# [79]	validation_0-rmse:0.12137
# [80]	validation_0-rmse:0.12088
# [81]	validation_0-rmse:0.12068
# [82]	validation_0-rmse:0.11992
# [83]	validation_0-rmse:0.11938
# [84]	validation_0-rmse:0.11903
# [85]	validation_0-rmse:0.11883
# [86]	validation_0-rmse:0.11813
# [87]	validation_0-rmse:0.11764
# [88]	validation_0-rmse:0.11719
# [89]	validation_0-rmse:0.11700
# [90]	validation_0-rmse:0.11651
# [91]	validation_0-rmse:0.11634
# [92]	validation_0-rmse:0.11607
# [93]	validation_0-rmse:0.11581
# [94]	validation_0-rmse:0.11538
# [95]	validation_0-rmse:0.11535
# [96]	validation_0-rmse:0.11528
# [97]	validation_0-rmse:0.11514
# [98]	validation_0-rmse:0.11473
# [99]	validation_0-rmse:0.11450
# [100]	validation_0-rmse:0.11423
# [101]	validation_0-rmse:0.11423
# [102]	validation_0-rmse:0.11378
# [103]	validation_0-rmse:0.11357
# [104]	validation_0-rmse:0.11342
# [105]	validation_0-rmse:0.11298
# [106]	validation_0-rmse:0.11295
# [107]	validation_0-rmse:0.11272
# [108]	validation_0-rmse:0.11275
# [109]	validation_0-rmse:0.11272
# [110]	validation_0-rmse:0.11280
# [111]	validation_0-rmse:0.11291
# [112]	validation_0-rmse:0.11298
# [113]	validation_0-rmse:0.11277
# [114]	validation_0-rmse:0.11265
# [115]	validation_0-rmse:0.11257
# [116]	validation_0-rmse:0.11235
# [117]	validation_0-rmse:0.11220
# [118]	validation_0-rmse:0.11212
# [119]	validation_0-rmse:0.11194
# [120]	validation_0-rmse:0.11172
# [121]	validation_0-rmse:0.11162
# [122]	validation_0-rmse:0.11147
# [123]	validation_0-rmse:0.11135
# [124]	validation_0-rmse:0.11129
# [125]	validation_0-rmse:0.11106
# [126]	validation_0-rmse:0.11080
# [127]	validation_0-rmse:0.11055
# [128]	validation_0-rmse:0.11026
# [129]	validation_0-rmse:0.11025
# [130]	validation_0-rmse:0.11003
# [131]	validation_0-rmse:0.10968
# [132]	validation_0-rmse:0.10963
# [133]	validation_0-rmse:0.10956
# [134]	validation_0-rmse:0.10962
# [135]	validation_0-rmse:0.10961
# [136]	validation_0-rmse:0.10955
# [137]	validation_0-rmse:0.10957
# [138]	validation_0-rmse:0.10919
# [139]	validation_0-rmse:0.10908
# [140]	validation_0-rmse:0.10900
# [141]	validation_0-rmse:0.10900
# [142]	validation_0-rmse:0.10890
# [143]	validation_0-rmse:0.10873
# [144]	validation_0-rmse:0.10860
# [145]	validation_0-rmse:0.10848
# [146]	validation_0-rmse:0.10872
# [147]	validation_0-rmse:0.10880
# [148]	validation_0-rmse:0.10890
# [149]	validation_0-rmse:0.10897
# [150]	validation_0-rmse:0.10868
# [151]	validation_0-rmse:0.10871
# [152]	validation_0-rmse:0.10870
# [153]	validation_0-rmse:0.10868
# [154]	validation_0-rmse:0.10867
# [155]	validation_0-rmse:0.10854
# [156]	validation_0-rmse:0.10850
# [157]	validation_0-rmse:0.10854
# [158]	validation_0-rmse:0.10834
# [159]	validation_0-rmse:0.10838
# [160]	validation_0-rmse:0.10826
# [161]	validation_0-rmse:0.10818
# [162]	validation_0-rmse:0.10802
# [163]	validation_0-rmse:0.10801
# [164]	validation_0-rmse:0.10811
# [165]	validation_0-rmse:0.10807
# [166]	validation_0-rmse:0.10800
# [167]	validation_0-rmse:0.10798
# [168]	validation_0-rmse:0.10801
# [169]	validation_0-rmse:0.10794
# [170]	validation_0-rmse:0.10788
# [171]	validation_0-rmse:0.10787
# [172]	validation_0-rmse:0.10789
# [173]	validation_0-rmse:0.10787
# [174]	validation_0-rmse:0.10781
# [175]	validation_0-rmse:0.10775
# [176]	validation_0-rmse:0.10772
# [177]	validation_0-rmse:0.10767
# [178]	validation_0-rmse:0.10754
# [179]	validation_0-rmse:0.10753
# [180]	validation_0-rmse:0.10742
# [181]	validation_0-rmse:0.10758
# [182]	validation_0-rmse:0.10760
# [183]	validation_0-rmse:0.10768
# [184]	validation_0-rmse:0.10767
# [185]	validation_0-rmse:0.10776
# [186]	validation_0-rmse:0.10777
# [187]	validation_0-rmse:0.10770
# [188]	validation_0-rmse:0.10768
# [189]	validation_0-rmse:0.10765
# [190]	validation_0-rmse:0.10764
# [191]	validation_0-rmse:0.10755
# [192]	validation_0-rmse:0.10766
# [193]	validation_0-rmse:0.10769
# [194]	validation_0-rmse:0.10759
# [195]	validation_0-rmse:0.10768
# [196]	validation_0-rmse:0.10767
# [197]	validation_0-rmse:0.10765
# [198]	validation_0-rmse:0.10753
# [199]	validation_0-rmse:0.10753
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# Best Ridge parameters found: {'alpha': 10.0}
# Holdout RMSE (Ridge): 26133.69519708773
# Submission file created: submission.csv
